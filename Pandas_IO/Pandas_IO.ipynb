# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/superstore_data.csv'

# %%
df = pd.read_csv(url, sep=',')

# %%
df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome
# 0   1826        1970  Graduation       Divorced  84835.0        0         0  \
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts
# 0   6/16/2014        0       189  ...              111               189  \
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases
# 0           218                  1                4                    4  \
# 1            37                  1                7                    3
# 2            30                  1                3                    2
# 3             0                  1                1                    0
# 4            34                  2                3                    1
#
#    NumStorePurchases  NumWebVisitsMonth  Response  Complain
# 0                  6                  1         1         0
# 1                  7                  5         1         0
# 2                  5                  2         0         0
# 3                  2                  7         0         0
# 4                  2                  7         1         0
#
# [5 rows x 22 columns]

# %%
url_2 = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/superstore_data_ponto_virgula.csv'

# %%
df_2 = pd.read_csv(url_2, sep=';')

# %%
df_2.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome
# 0   1826        1970  Graduation       Divorced  84835.0        0         0  \
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts
# 0   6/16/2014        0       189  ...              111               189  \
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases
# 0           218                  1                4                    4  \
# 1            37                  1                7                    3
# 2            30                  1                3                    2
# 3             0                  1                1                    0
# 4            34                  2                3                    1
#
#    NumStorePurchases  NumWebVisitsMonth  Response  Complain
# 0                  6                  1         1         0
# 1                  7                  5         1         0
# 2                  5                  2         0         0
# 3                  2                  7         0         0
# 4                  2                  7         1         0
#
# [5 rows x 22 columns]

# %%
df_primeiras_linhas = pd.read_csv(url, nrows=5)
df_primeiras_linhas
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome
# 0   1826        1970  Graduation       Divorced   84835        0         0  \
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts
# 0   6/16/2014        0       189  ...              111               189  \
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases
# 0           218                  1                4                    4  \
# 1            37                  1                7                    3
# 2            30                  1                3                    2
# 3             0                  1                1                    0
# 4            34                  2                3                    1
#
#    NumStorePurchases  NumWebVisitsMonth  Response  Complain
# 0                  6                  1         1         0
# 1                  7                  5         1         0
# 2                  5                  2         0         0
# 3                  2                  7         0         0
# 4                  2                  7         1         0
#
# [5 rows x 22 columns]

# %%
df_selecao = pd.read_csv(url, usecols=['Id', 'Year_Birth', 'Income'])
df_selecao
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
df_selecao = pd.read_csv(url, usecols=[0,1,4])
df_selecao
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
df_selecao.to_csv('clientes_mercado.csv', index=False)

# %%
clientes_mercado = pd.read_csv('clientes_mercado.csv')
clientes_mercado
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# A biblioteca Pandas é uma das ferramentas mais poderosas disponíveis para a análise de dados em Python. Ela oferece uma ampla variedade de funcionalidades que tornam o processo de manipulação e análise de dados muito mais fácil e eficiente.
#
# Para aproveitar ao máximo todas as funcionalidades da biblioteca, é essencial explorar a sua documentação, que é extensa e bem organizada, e pode ser facilmente acessada no modo on-line. Confira as indicações:
#
# Função read_csv
# Função to_csv
# Explorar a documentação da biblioteca é importante por diversas razões. Ela pode ajudar a entender como as funções e métodos da biblioteca funcionam e como elas podem ser usadas para analisar e manipular os dados.
#
# Além disso, a documentação fornece detalhes sobre os parâmetros de cada função e exemplos de como eles podem ser usados na prática. Então, busque aprofundar os seus estudos nesses parâmetros das funções read_csv e to_csv e aprenda mais sobre cada um deles.

# %% [markdown]
# Chegou a hora de você testar os conhecimentos desenvolvidos durante a aula. Temos um arquivo no formato CSV, que foi obtido na página Informações de Saúde (TABNET) - DATASUS. Este arquivo contém os gastos hospitalares públicos de cada uma das Unidades da Federação brasileira no período de janeiro de 2008 a março de 2021.
#
# Seu desafio aqui será fazer a leitura desse arquivo utilizando a função read_csv da biblioteca Pandas. Alguns parâmetros devem ser adicionados para que a leitura seja feita corretamente. Então, seguem algumas dicas:
#
# Verifique se o arquivo CSV está separado por vírgula ou ponto e vírgula.
# A codificação do arquivo é ISO-8859-1.
# As três primeiras linhas linhas do arquivo podem ser desconsideradas, pois o cabeçalho só começa na quarta linha.
# As 9 últimas linhas também podem ser desconsideradas, pois são apenas informações sobre onde os dados foram obtidos.
# Para deletar as últimas linhas é necessário adicionar o parâmetro engine='python'.
#
# Para fazer a leitura do arquivo podemos começar armazenando o endereço em uma variável chamada url:
#
# url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/dados_sus.csv'COPIAR CÓDIGO
# Em seguida, podemos ler a url com a função read_csv e adicionar os parâmetros:
#
# encoding='ISO-8859-1': tipo de codificação dos caracteres do arquivo. Neste caso, é a codificação ISO-8859-1 que é comum em arquivos de língua portuguesa.
# sep=';': separador dos valores no arquivo. Neste caso, é o ponto-e-vírgula (;).
# skiprows=3: indica que as três primeiras linhas do arquivo devem ser ignoradas, pois não contêm dados relevantes.
# skipfooter = 9: indica que as nove últimas linhas do arquivo devem ser ignoradas, pois não contêm dados relevantes.
# engine='python': o motor usado para ler o arquivo é o Python. Isso é necessário quando se usa o parâmetro skipfooter, pois o motor padrão não suporta essa opção.
# dados = pd.read_csv(url, encoding='ISO-8859-1', sep=';', skiprows=3, skipfooter = 9, engine='python')COPIAR CÓDIGO
# Dessa forma os dados serão carregados com sucesso!

# %%
url = 'https://github.com/alura-cursos/Pandas/blob/main/emissoes_CO2.xlsx?raw=True'

# %%
df_co2 = pd.read_excel(url)

# %%
df_co2.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Oléo  Gás  Cimento
# 0  Afeganistão                AFG  1750    0.0     NaN   NaN  NaN      NaN  \
# 1  Afeganistão                AFG  1751    0.0     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    0.0     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    0.0     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    0.0     NaN   NaN  NaN      NaN
#
#    Queima  Outro  Per Capita
# 0     NaN    NaN         NaN
# 1     NaN    NaN         NaN
# 2     NaN    NaN         NaN
# 3     NaN    NaN         NaN
# 4     NaN    NaN         NaN

# %%
pd.ExcelFile(url).sheet_names
# Out:
# ['emissoes_C02', 'emissoes_percapita', 'fontes']

# %%
percapita = pd.read_excel(url, sheet_name='emissoes_percapita')

# %%
percapita.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Óleo  Gás  Cimento
# 0  Afeganistão                AFG  1750    NaN     NaN   NaN  NaN      NaN  \
# 1  Afeganistão                AFG  1751    NaN     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    NaN     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    NaN     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    NaN     NaN   NaN  NaN      NaN
#
#    Queima  Outro
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN

# %%
fontes = pd.read_excel(url, sheet_name='fontes')

# %%
fontes.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano   Total  Carvão    Oléo     Gás
# 0  Afeganistão                AFG  1750  [NONE]  [NONE]  [NONE]  [NONE]  \
# 1  Afeganistão                AFG  1751  [NONE]  [NONE]  [NONE]  [NONE]
# 2  Afeganistão                AFG  1752  [NONE]  [NONE]  [NONE]  [NONE]
# 3  Afeganistão                AFG  1753  [NONE]  [NONE]  [NONE]  [NONE]
# 4  Afeganistão                AFG  1754  [NONE]  [NONE]  [NONE]  [NONE]
#
#   Cimento  Queima   Outro Per Capita
# 0  [NONE]  [NONE]  [NONE]     [NONE]
# 1  [NONE]  [NONE]  [NONE]     [NONE]
# 2  [NONE]  [NONE]  [NONE]     [NONE]
# 3  [NONE]  [NONE]  [NONE]     [NONE]
# 4  [NONE]  [NONE]  [NONE]     [NONE]

# %%
intervalo = pd.read_excel(url, sheet_name='emissoes_C02', usecols='A:D')

# %%
intervalo_2 = pd.read_excel(url, sheet_name='emissoes_C02', usecols='A:D', nrows=10)

# %%
intervalo.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total
# 0  Afeganistão                AFG  1750    0.0
# 1  Afeganistão                AFG  1751    0.0
# 2  Afeganistão                AFG  1752    0.0
# 3  Afeganistão                AFG  1753    0.0
# 4  Afeganistão                AFG  1754    0.0

# %%
intervalo_2.head(15)
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total
# 0  Afeganistão                AFG  1750      0
# 1  Afeganistão                AFG  1751      0
# 2  Afeganistão                AFG  1752      0
# 3  Afeganistão                AFG  1753      0
# 4  Afeganistão                AFG  1754      0
# 5  Afeganistão                AFG  1755      0
# 6  Afeganistão                AFG  1756      0
# 7  Afeganistão                AFG  1757      0
# 8  Afeganistão                AFG  1758      0
# 9  Afeganistão                AFG  1759      0

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/pacientes.json'

# %%
df_pacientes = pd.read_json(url)

# %%
df_pacientes
# Out:
#      ID_paciente Doenca_cardiaca    IMC Fumante Consumo_alcool  AVC
# 0              0             Nao  16.60     Sim            Nao  Nao  \
# 1              1             Nao  20.34     Nao            Nao  Sim
# 2              2             Nao  26.58     Sim            Nao  Nao
# 3              3             Nao  24.21     Nao            Nao  Nao
# 4              4             Nao  23.71     Nao            Nao  Nao
# ..           ...             ...    ...     ...            ...  ...
# 995          995             Nao  28.29     Sim            Nao  Nao
# 996          996             Nao  25.69     Sim            Nao  Nao
# 997          997             Sim  26.99     Nao            Nao  Nao
# 998          998             Nao  44.29     Nao            Nao  Nao
# 999          999             Nao  25.83     Nao            Nao  Nao
#
#      Saude_fisica  Saude_mental Dificuldade_caminhar Sexo_biologico
# 0               3            30                  Nao       Feminino  \
# 1               0             0                  Nao       Feminino
# 2              20            30                  Nao      Masculino
# 3               0             0                  Nao       Feminino
# 4              28             0                  Sim       Feminino
# ..            ...           ...                  ...            ...
# 995            10            20                  Nao       Feminino
# 996             0             0                  Nao       Feminino
# 997             1             0                  Nao      Masculino
# 998            30             0                  Sim       Feminino
# 999             0             0                  Nao      Masculino
#
#     Faixa_etaria    Raca Diabetes Atividade_fisica Saude_geral  Horas_sono
# 0          55-59  Branca      Sim              Sim   Muito boa           5  \
# 1        80 ou +  Branca      Nao              Sim   Muito boa           7
# 2          65-69  Branca      Sim              Sim    Razoavel           8
# 3          75-79  Branca      Nao               No         Boa           6
# 4          40-44  Branca      Nao              Sim   Muito boa           8
# ..           ...     ...      ...              ...         ...         ...
# 995        65-69   Preta      Sim              Sim    Razoavel           8
# 996        75-79  Branca      Nao              Sim   Excelente           8
# 997        70-74  Branca      Nao              Sim   Muito boa           8
# 998        70-74  Branca      Sim               No         Boa           6
# 999        70-74   Preta      Sim               No   Excelente           7
#
#     Asma Doenca_renal Cancer_pele
# 0    Sim          Nao         Sim
# 1    Nao          Nao         Nao
# 2    Sim          Nao         Nao
# 3    Nao          Nao         Sim
# 4    Nao          Nao         Nao
# ..   ...          ...         ...
# 995  Nao          Nao         Nao
# 996  Nao          Nao         Nao
# 997  Nao          Nao         Nao
# 998  Sim          Nao         Nao
# 999  Nao          Nao         Nao
#
# [1000 rows x 19 columns]

# %%
url_2 = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/pacientes_2.json'

# %%
df_pacientes_2 = pd.read_json(url_2)

# %%
df_pacientes_2
# Out:
#                                     Pesquisa   Ano
# 0  Principais Indicadores de Doenca Cardiaca  2020  \
# 1  Principais Indicadores de Doenca Cardiaca  2020
# 2  Principais Indicadores de Doenca Cardiaca  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Faixa_etaria': '55-59', 'Sexo_bi...
# 1  {'ID': '02', 'Faixa_etaria': '80 ou +', 'Sexo_...
# 2  {'ID': '03', 'Faixa_etaria': '65-69', 'Sexo_bi...

# %%
df_normalizado = pd.json_normalize(df_pacientes_2['Pacientes'])

# %%
df_normalizado
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool
# 0  01        55-59       Feminino  Branca  16.60     Sim            Nao  \
# 1  02      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2  03        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica
# 0             3            30                  Nao              Sim  \
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]

# %%
pip install sqlalchemy
# Out:
# Collecting sqlalchemy
#   Downloading SQLAlchemy-2.0.16-cp311-cp311-win_amd64.whl (2.0 MB)
#                                               0.0/2.0 MB ? eta -:--:--
#      ----                                     0.2/2.0 MB 4.1 MB/s eta 0:00:01
#      -----------                              0.6/2.0 MB 5.8 MB/s eta 0:00:01
#      -----------                              0.6/2.0 MB 4.0 MB/s eta 0:00:01
#      --------------------------               1.3/2.0 MB 6.9 MB/s eta 0:00:01
#      -----------------------------------      1.8/2.0 MB 7.5 MB/s eta 0:00:01
#      ---------------------------------------- 2.0/2.0 MB 7.4 MB/s eta 0:00:00
# Collecting typing-extensions>=4.2.0 (from sqlalchemy)
#   Downloading typing_extensions-4.6.3-py3-none-any.whl (31 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy)
#   Downloading greenlet-2.0.2-cp311-cp311-win_amd64.whl (192 kB)
#                                               0.0/192.5 kB ? eta -:--:--
#      ------------------------------------- 192.5/192.5 kB 11.4 MB/s eta 0:00:00
# Installing collected packages: typing-extensions, greenlet, sqlalchemy
# Successfully installed greenlet-2.0.2 sqlalchemy-2.0.16 typing-extensions-4.6.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect

# %%
engine = create_engine('sqlite:///:memory:')

# %%
url_cliente = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/clientes_banco.csv'

# %%
df = pd.read_csv(url_cliente)

# %%
df.head()
# Out:
#    ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia
# 0     5008804     32   Ensino superior  União-estável                2  \
# 1     5008805     32   Ensino superior  União-estável                2
# 2     5008806     58      Ensino médio         Casado                2
# 3     5008808     52      Ensino médio       Solteiro                1
# 4     5008809     52      Ensino médio       Solteiro                1
#
#     Categoria_de_renda   Ocupacao  Anos_empregado  Rendimento_anual
# 0            Empregado      Outro              12          427500.0  \
# 1            Empregado      Outro              12          427500.0
# 2            Empregado  Segurança               3          112500.0
# 3  Associado comercial     Vendas               8          270000.0
# 4  Associado comercial     Vendas               8          270000.0
#
#    Tem_carro                   Moradia
# 0          1       Apartamento alugado
# 1          1       Apartamento alugado
# 2          1  Casa/apartamento próprio
# 3          0  Casa/apartamento próprio
# 4          0  Casa/apartamento próprio

# %%
df.to_sql('clientes', engine, index=False)
# Out:
# 438463

# %%
inspector = inspect(engine)

# %%
print(inspector.get_table_names())
# Out:
# ['clientes']

# %%
query = 'Select * From clientes Where Categoria_de_renda= "Empregado"'

# %%
empregados = pd.read_sql(query, engine)

# %%
empregados
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia
# 0          5008804     32   Ensino superior  União-estável                2  \
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008815     46   Ensino superior         Casado                2
# 4          5112956     46   Ensino superior         Casado                2
# ...            ...    ...               ...            ...              ...
# 226054     6837905     43      Ensino médio         Casado                3
# 226055     6837906     43      Ensino médio         Casado                3
# 226056     6839936     34      Ensino médio         Casado                3
# 226057     6840222     43      Ensino médio       Solteiro                1
# 226058     6842885     51      Ensino médio         Casado                2
#
#        Categoria_de_renda          Ocupacao  Anos_empregado  Rendimento_anual
# 0               Empregado             Outro              12          427500.0  \
# 1               Empregado             Outro              12          427500.0
# 2               Empregado         Segurança               3          112500.0
# 3               Empregado     Contabilidade               2          270000.0
# 4               Empregado     Contabilidade               2          270000.0
# ...                   ...               ...             ...               ...
# 226054          Empregado             Outro               7          355050.0
# 226055          Empregado             Outro               7          355050.0
# 226056          Empregado  Construção Civil               5          135000.0
# 226057          Empregado  Construção Civil               8          103500.0
# 226058          Empregado            Vendas               3          121500.0
#
#         Tem_carro                   Moradia
# 0               1       Apartamento alugado
# 1               1       Apartamento alugado
# 2               1  Casa/apartamento próprio
# 3               1  Casa/apartamento próprio
# 4               1  Casa/apartamento próprio
# ...           ...                       ...
# 226054          1  Casa/apartamento próprio
# 226055          1  Casa/apartamento próprio
# 226056          1  Casa/apartamento próprio
# 226057          0  Casa/apartamento próprio
# 226058          0  Casa/apartamento próprio
#
# [226059 rows x 11 columns]

# %%
empregados.to_sql('empregados', con=engine, index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 empregados.to_sql('empregados', con=engine, index=False)
#
# File c:\Users\eldiniz\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File c:\Users\eldiniz\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:767, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     762     raise NotImplementedError(
#     763         "'frame' argument should be either a Series or a DataFrame"
#     764     )
#     766 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 767     return pandas_sql.to_sql(
#     768         frame,
#     769         name,
#     770         if_exists=if_exists,
#     771         index=index,
#     772         index_label=index_label,
#     773         schema=schema,
#     774         chunksize=chunksize,
#     775         dtype=dtype,
#     776         method=method,
#     777         engine=engine,
#     778         **engine_kwargs,
#     779     )
#
# File c:\Users\eldiniz\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:1908, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1858 """
#    1859 Write records stored in a DataFrame to a SQL database.
#    1860
#    (...)
#    1904     Any additional kwargs are passed to the engine.
#    1905 """
#    1906 sql_engine = get_engine(engine)
# -> 1908 table = self.prep_table(
#    1909     frame=frame,
#    1910     name=name,
#    1911     if_exists=if_exists,
#    1912     index=index,
#    1913     index_label=index_label,
#    1914     schema=schema,
#    1915     dtype=dtype,
#    1916 )
#    1918 total_inserted = sql_engine.insert_records(
#    1919     table=table,
#    1920     con=self.con,
#    (...)
#    1927     **engine_kwargs,
#    1928 )
#    1930 self.check_case_sensitive(name=name, schema=schema)
#
# File c:\Users\eldiniz\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:1812, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1800             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1802 table = SQLTable(
#    1803     name,
#    1804     self,
#    (...)
#    1810     dtype=dtype,
#    1811 )
# -> 1812 table.create()
#    1813 return table
#
# File c:\Users\eldiniz\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:903, in SQLTable.create(self)
#     901 if self.exists():
#     902     if self.if_exists == "fail":
# --> 903         raise ValueError(f"Table '{self.name}' already exists.")
#     904     if self.if_exists == "replace":
#     905         self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'empregados' already exists.

# %%
pd.read_sql_table('empregados', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia
# 0          5008804     32   Ensino superior  União-estável                2  \
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008815     46   Ensino superior         Casado                2
# 4          5112956     46   Ensino superior         Casado                2
# ...            ...    ...               ...            ...              ...
# 226054     6837905     43      Ensino médio         Casado                3
# 226055     6837906     43      Ensino médio         Casado                3
# 226056     6839936     34      Ensino médio         Casado                3
# 226057     6840222     43      Ensino médio       Solteiro                1
# 226058     6842885     51      Ensino médio         Casado                2
#
#        Categoria_de_renda          Ocupacao  Anos_empregado  Rendimento_anual
# 0               Empregado             Outro              12          427500.0  \
# 1               Empregado             Outro              12          427500.0
# 2               Empregado         Segurança               3          112500.0
# 3               Empregado     Contabilidade               2          270000.0
# 4               Empregado     Contabilidade               2          270000.0
# ...                   ...               ...             ...               ...
# 226054          Empregado             Outro               7          355050.0
# 226055          Empregado             Outro               7          355050.0
# 226056          Empregado  Construção Civil               5          135000.0
# 226057          Empregado  Construção Civil               8          103500.0
# 226058          Empregado            Vendas               3          121500.0
#
#         Tem_carro                   Moradia
# 0               1       Apartamento alugado
# 1               1       Apartamento alugado
# 2               1  Casa/apartamento próprio
# 3               1  Casa/apartamento próprio
# 4               1  Casa/apartamento próprio
# ...           ...                       ...
# 226054          1  Casa/apartamento próprio
# 226055          1  Casa/apartamento próprio
# 226056          1  Casa/apartamento próprio
# 226057          0  Casa/apartamento próprio
# 226058          0  Casa/apartamento próprio
#
# [226059 rows x 11 columns]
